# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import cv2
import os
import numpy as np
import glob
from PIL import Image

# %%
def random_shearing(img, num, border):
    rows = img.shape[0]
    cols = img.shape[1]
    if num == 0:
        pts1 = np.float32([[5,5],[20,5],[2,20]])
        pts2 = np.float32([[10,10],[20,5],[5,25]])
    elif num == 1:
        pts1 = np.float32([[5,5],[15,5],[2,20]])
        pts2 = np.float32([[5,10],[10,10],[5,25]])
    elif num == 2:
        pts1 = np.float32([[5,5],[15,5],[5,20]])
        pts2 = np.float32([[5,10],[10,10],[5,25]])
    elif num == 3:
        pts1 = np.float32([[5,5],[10,5],[2,20]])
        pts2 = np.float32([[5,10],[10,10],[5,25]])
    elif num == 4:
        pts1 = np.float32([[5,5],[10,5],[2,20]])
        pts2 = np.float32([[5,10],[10,10],[5,30]])
    else:
        pts1 = np.float32([[5,5],[10,5],[10,20]])
        pts2 = np.float32([[5,10],[10,10],[5,30]])
    M = cv2.getAffineTransform(pts1,pts2)
    return cv2.warpAffine(img, M, (cols,rows), borderValue=border)

def random_rotation(img, degree, border):
    rows = img.shape[0]
    cols = img.shape[1]
    M = cv2.getRotationMatrix2D((cols/2,rows/2),degree,1)
    return cv2.warpAffine(img,M,(cols,rows), borderValue=border)

# %%
def transform_image(img, skt, ang_range, shear_range, trans_range):
    '''
    This function transforms images to generate new images.
    The function takes in following arguments,
    1- Image
    2- ang_range: Range of angles for rotation
    3- shear_range: Range of values to apply affine transform to
    4- trans_range: Range of values to apply translations over.

    A Random uniform distribution is used to generate different parameters for transformation

    '''
    # Rotation

    ang_rot = np.random.uniform(ang_range)-ang_range/2
    rows,cols,ch = img.shape
    Rot_M = cv2.getRotationMatrix2D((cols/2,rows/2),ang_rot,1)

    # Translation
    tr_x = trans_range*np.random.uniform()-trans_range/2
    tr_y = trans_range*np.random.uniform()-trans_range/2
    Trans_M = np.float32([[1,0,tr_x],[0,1,tr_y]])

    # Shear
    pts1 = np.float32([[5,5],[20,5],[5,20]])

    pt1 = 5+shear_range*np.random.uniform()-shear_range/2
    pt2 = 20+shear_range*np.random.uniform()-shear_range/2

    pts2 = np.float32([[pt1,5],[pt2,pt1],[5,pt2]])

    shear_M = cv2.getAffineTransform(pts1,pts2)

    # Border
    idx = 0
    border_img = tuple([int(img[idx][0][0]), int(img[idx][0][1]), int(img[idx][0][2])])
    border_skt = tuple([int(skt[0][0][0]), int(skt[0][0][1]), int(skt[0][0][2])])

    img = cv2.warpAffine(img,Rot_M,(cols,rows), borderValue=border_img)
    img = cv2.warpAffine(img,Trans_M,(cols,rows), borderValue=border_img)
    img = cv2.warpAffine(img,shear_M,(cols,rows), borderValue=border_img)

    skt = cv2.warpAffine(skt,Rot_M,(cols,rows), borderValue=border_skt)
    skt = cv2.warpAffine(skt,Trans_M,(cols,rows), borderValue=border_skt)
    skt = cv2.warpAffine(skt,shear_M,(cols,rows), borderValue=border_skt)

    return img, skt

# %%
# sketch_dir = '/content/gdrive/MyDrive/F-to-S/Dataset/New_Augmented_sketch/'
# photo_dir = '/content/gdrive/MyDrive/F-to-S/Dataset/New_Augmented_photo/'

# if not os.path.exists(sketch_dir):
#     os.mkdir(sketch_dir)

# if not os.path.exists(photo_dir):
#     os.mkdir(photo_dir)

# p_filenames = glob.glob('/content/gdrive/MyDrive/F-to-S/Dataset/Training photo/*')
# s_filenames = glob.glob('/content/gdrive/MyDrive/F-to-S/Dataset/Training sketch/*')

# counter = 0
# for i in range(len(p_filenames)):
#     im = cv2.imread(p_filenames[i])
#     sk = cv2.imread(s_filenames[i])

#     for j in range(200):
#         img, skt = transform_image(im, sk, 40, 10, 10)

#         cv2.imwrite(photo_dir + str(counter) + '.jpg', img)
#         cv2.imwrite(sketch_dir + str(counter) + '.jpg', skt)

#         counter += 1

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://www.github.com/keras-team/keras-contrib.git
# Out:
# Cloning into 'keras-contrib'...
# warning: redirecting to https://github.com/keras-team/keras-contrib.git/
# remote: Enumerating objects: 3634, done.
# remote: Total 3634 (delta 0), reused 0 (delta 0), pack-reused 3634
# Receiving objects: 100% (3634/3634), 861.24 KiB | 10.01 MiB/s, done.
# Resolving deltas: 100% (2330/2330), done.

# %%
# %cd keras-contrib
# !python setup.py install
# Out:
# /content/keras-contrib
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating keras_contrib.egg-info
# writing keras_contrib.egg-info/PKG-INFO
# writing dependency_links to keras_contrib.egg-info/dependency_links.txt
# writing requirements to keras_contrib.egg-info/requires.txt
# writing top-level names to keras_contrib.egg-info/top_level.txt
# writing manifest file 'keras_contrib.egg-info/SOURCES.txt'
# reading manifest file 'keras_contrib.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'keras_contrib.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/keras_contrib
# copying keras_contrib/__init__.py -> build/lib/keras_contrib
# creating build/lib/keras_contrib/optimizers
# copying keras_contrib/optimizers/padam.py -> build/lib/keras_contrib/optimizers
# copying keras_contrib/optimizers/yogi.py -> build/lib/keras_contrib/optimizers
# copying keras_contrib/optimizers/ftml.py -> build/lib/keras_contrib/optimizers
# copying keras_contrib/optimizers/__init__.py -> build/lib/keras_contrib/optimizers
# copying keras_contrib/optimizers/lars.py -> build/lib/keras_contrib/optimizers
# creating build/lib/keras_contrib/wrappers
# copying keras_contrib/wrappers/__init__.py -> build/lib/keras_contrib/wrappers
# creating build/lib/keras_contrib/backend
# copying keras_contrib/backend/numpy_backend.py -> build/lib/keras_contrib/backend
# copying keras_contrib/backend/cntk_backend.py -> build/lib/keras_contrib/backend
# copying keras_contrib/backend/__init__.py -> build/lib/keras_contrib/backend
# copying keras_contrib/backend/theano_backend.py -> build/lib/keras_contrib/backend
# copying keras_contrib/backend/tensorflow_backend.py -> build/lib/keras_contrib/backend
# creating build/lib/keras_contrib/preprocessing
# copying keras_contrib/preprocessing/__init__.py -> build/lib/keras_contrib/preprocessing
# creating build/lib/keras_contrib/utils
# copying keras_contrib/utils/save_load_utils.py -> build/lib/keras_contrib/utils
# copying keras_contrib/utils/__init__.py -> build/lib/keras_contrib/utils
# copying keras_contrib/utils/conv_utils.py -> build/lib/keras_contrib/utils
# copying keras_contrib/utils/test_utils.py -> build/lib/keras_contrib/utils
# creating build/lib/keras_contrib/callbacks
# copying keras_contrib/callbacks/snapshot.py -> build/lib/keras_contrib/callbacks
# copying keras_contrib/callbacks/dead_relu_detector.py -> build/lib/keras_contrib/callbacks
# copying keras_contrib/callbacks/__init__.py -> build/lib/keras_contrib/callbacks
# copying keras_contrib/callbacks/tensorboard.py -> build/lib/keras_contrib/callbacks
# copying keras_contrib/callbacks/cyclical_learning_rate.py -> build/lib/keras_contrib/callbacks
# creating build/lib/keras_contrib/constraints
# copying keras_contrib/constraints/clip.py -> build/lib/keras_contrib/constraints
# copying keras_contrib/constraints/__init__.py -> build/lib/keras_contrib/constraints
# creating build/lib/keras_contrib/applications
# copying keras_contrib/applications/densenet.py -> build/lib/keras_contrib/applications
# copying keras_contrib/applications/__init__.py -> build/lib/keras_contrib/applications
# copying keras_contrib/applications/nasnet.py -> build/lib/keras_contrib/applications
# copying keras_contrib/applications/resnet.py -> build/lib/keras_contrib/applications
# copying keras_contrib/applications/wide_resnet.py -> build/lib/keras_contrib/applications
# creating build/lib/keras_contrib/activations
# copying keras_contrib/activations/__init__.py -> build/lib/keras_contrib/activations
# copying keras_contrib/activations/squash.py -> build/lib/keras_contrib/activations
# creating build/lib/keras_contrib/metrics
# copying keras_contrib/metrics/__init__.py -> build/lib/keras_contrib/metrics
# copying keras_contrib/metrics/crf_accuracies.py -> build/lib/keras_contrib/metrics
# creating build/lib/keras_contrib/regularizers
# copying keras_contrib/regularizers/__init__.py -> build/lib/keras_contrib/regularizers
# creating build/lib/keras_contrib/losses
# copying keras_contrib/losses/crf_losses.py -> build/lib/keras_contrib/losses
# copying keras_contrib/losses/__init__.py -> build/lib/keras_contrib/losses
# copying keras_contrib/losses/jaccard.py -> build/lib/keras_contrib/losses
# copying keras_contrib/losses/dssim.py -> build/lib/keras_contrib/losses
# creating build/lib/keras_contrib/tests
# copying keras_contrib/tests/activations.py -> build/lib/keras_contrib/tests
# copying keras_contrib/tests/regularizers.py -> build/lib/keras_contrib/tests
# copying keras_contrib/tests/optimizers.py -> build/lib/keras_contrib/tests
# copying keras_contrib/tests/__init__.py -> build/lib/keras_contrib/tests
# copying keras_contrib/tests/metrics.py -> build/lib/keras_contrib/tests
# creating build/lib/keras_contrib/datasets
# copying keras_contrib/datasets/coco.py -> build/lib/keras_contrib/datasets
# copying keras_contrib/datasets/pascal_voc.py -> build/lib/keras_contrib/datasets
# copying keras_contrib/datasets/__init__.py -> build/lib/keras_contrib/datasets
# copying keras_contrib/datasets/conll2000.py -> build/lib/keras_contrib/datasets
# creating build/lib/keras_contrib/layers
# copying keras_contrib/layers/crf.py -> build/lib/keras_contrib/layers
# copying keras_contrib/layers/capsule.py -> build/lib/keras_contrib/layers
# copying keras_contrib/layers/__init__.py -> build/lib/keras_contrib/layers
# copying keras_contrib/layers/core.py -> build/lib/keras_contrib/layers
# creating build/lib/keras_contrib/initializers
# copying keras_contrib/initializers/convaware.py -> build/lib/keras_contrib/initializers
# copying keras_contrib/initializers/__init__.py -> build/lib/keras_contrib/initializers
# creating build/lib/keras_contrib/layers/normalization
# copying keras_contrib/layers/normalization/instancenormalization.py -> build/lib/keras_contrib/layers/normalization
# copying keras_contrib/layers/normalization/__init__.py -> build/lib/keras_contrib/layers/normalization
# copying keras_contrib/layers/normalization/groupnormalization.py -> build/lib/keras_contrib/layers/normalization
# creating build/lib/keras_contrib/layers/convolutional
# copying keras_contrib/layers/convolutional/cosineconvolution2d.py -> build/lib/keras_contrib/layers/convolutional
# copying keras_contrib/layers/convolutional/subpixelupscaling.py -> build/lib/keras_contrib/layers/convolutional
# copying keras_contrib/layers/convolutional/__init__.py -> build/lib/keras_contrib/layers/convolutional
# creating build/lib/keras_contrib/layers/advanced_activations
# copying keras_contrib/layers/advanced_activations/srelu.py -> build/lib/keras_contrib/layers/advanced_activations
# copying keras_contrib/layers/advanced_activations/pelu.py -> build/lib/keras_contrib/layers/advanced_activations
# copying keras_contrib/layers/advanced_activations/sinerelu.py -> build/lib/keras_contrib/layers/advanced_activations
# copying keras_contrib/layers/advanced_activations/swish.py -> build/lib/keras_contrib/layers/advanced_activations
# copying keras_contrib/layers/advanced_activations/__init__.py -> build/lib/keras_contrib/layers/advanced_activations
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/keras_contrib
# creating build/bdist.linux-x86_64/egg/keras_contrib/optimizers
# copying build/lib/keras_contrib/optimizers/padam.py -> build/bdist.linux-x86_64/egg/keras_contrib/optimizers
# copying build/lib/keras_contrib/optimizers/yogi.py -> build/bdist.linux-x86_64/egg/keras_contrib/optimizers
# copying build/lib/keras_contrib/optimizers/ftml.py -> build/bdist.linux-x86_64/egg/keras_contrib/optimizers
# copying build/lib/keras_contrib/optimizers/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/optimizers
# copying build/lib/keras_contrib/optimizers/lars.py -> build/bdist.linux-x86_64/egg/keras_contrib/optimizers
# creating build/bdist.linux-x86_64/egg/keras_contrib/wrappers
# copying build/lib/keras_contrib/wrappers/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/wrappers
# creating build/bdist.linux-x86_64/egg/keras_contrib/backend
# copying build/lib/keras_contrib/backend/numpy_backend.py -> build/bdist.linux-x86_64/egg/keras_contrib/backend
# copying build/lib/keras_contrib/backend/cntk_backend.py -> build/bdist.linux-x86_64/egg/keras_contrib/backend
# copying build/lib/keras_contrib/backend/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/backend
# copying build/lib/keras_contrib/backend/theano_backend.py -> build/bdist.linux-x86_64/egg/keras_contrib/backend
# copying build/lib/keras_contrib/backend/tensorflow_backend.py -> build/bdist.linux-x86_64/egg/keras_contrib/backend
# creating build/bdist.linux-x86_64/egg/keras_contrib/preprocessing
# copying build/lib/keras_contrib/preprocessing/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/preprocessing
# creating build/bdist.linux-x86_64/egg/keras_contrib/utils
# copying build/lib/keras_contrib/utils/save_load_utils.py -> build/bdist.linux-x86_64/egg/keras_contrib/utils
# copying build/lib/keras_contrib/utils/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/utils
# copying build/lib/keras_contrib/utils/conv_utils.py -> build/bdist.linux-x86_64/egg/keras_contrib/utils
# copying build/lib/keras_contrib/utils/test_utils.py -> build/bdist.linux-x86_64/egg/keras_contrib/utils
# creating build/bdist.linux-x86_64/egg/keras_contrib/callbacks
# copying build/lib/keras_contrib/callbacks/snapshot.py -> build/bdist.linux-x86_64/egg/keras_contrib/callbacks
# copying build/lib/keras_contrib/callbacks/dead_relu_detector.py -> build/bdist.linux-x86_64/egg/keras_contrib/callbacks
# copying build/lib/keras_contrib/callbacks/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/callbacks
# copying build/lib/keras_contrib/callbacks/tensorboard.py -> build/bdist.linux-x86_64/egg/keras_contrib/callbacks
# copying build/lib/keras_contrib/callbacks/cyclical_learning_rate.py -> build/bdist.linux-x86_64/egg/keras_contrib/callbacks
# copying build/lib/keras_contrib/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib
# creating build/bdist.linux-x86_64/egg/keras_contrib/constraints
# copying build/lib/keras_contrib/constraints/clip.py -> build/bdist.linux-x86_64/egg/keras_contrib/constraints
# copying build/lib/keras_contrib/constraints/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/constraints
# creating build/bdist.linux-x86_64/egg/keras_contrib/applications
# copying build/lib/keras_contrib/applications/densenet.py -> build/bdist.linux-x86_64/egg/keras_contrib/applications
# copying build/lib/keras_contrib/applications/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/applications
# copying build/lib/keras_contrib/applications/nasnet.py -> build/bdist.linux-x86_64/egg/keras_contrib/applications
# copying build/lib/keras_contrib/applications/resnet.py -> build/bdist.linux-x86_64/egg/keras_contrib/applications
# copying build/lib/keras_contrib/applications/wide_resnet.py -> build/bdist.linux-x86_64/egg/keras_contrib/applications
# creating build/bdist.linux-x86_64/egg/keras_contrib/activations
# copying build/lib/keras_contrib/activations/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/activations
# copying build/lib/keras_contrib/activations/squash.py -> build/bdist.linux-x86_64/egg/keras_contrib/activations
# creating build/bdist.linux-x86_64/egg/keras_contrib/metrics
# copying build/lib/keras_contrib/metrics/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/metrics
# copying build/lib/keras_contrib/metrics/crf_accuracies.py -> build/bdist.linux-x86_64/egg/keras_contrib/metrics
# creating build/bdist.linux-x86_64/egg/keras_contrib/regularizers
# copying build/lib/keras_contrib/regularizers/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/regularizers
# creating build/bdist.linux-x86_64/egg/keras_contrib/losses
# copying build/lib/keras_contrib/losses/crf_losses.py -> build/bdist.linux-x86_64/egg/keras_contrib/losses
# copying build/lib/keras_contrib/losses/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/losses
# copying build/lib/keras_contrib/losses/jaccard.py -> build/bdist.linux-x86_64/egg/keras_contrib/losses
# copying build/lib/keras_contrib/losses/dssim.py -> build/bdist.linux-x86_64/egg/keras_contrib/losses
# creating build/bdist.linux-x86_64/egg/keras_contrib/tests
# copying build/lib/keras_contrib/tests/activations.py -> build/bdist.linux-x86_64/egg/keras_contrib/tests
# copying build/lib/keras_contrib/tests/regularizers.py -> build/bdist.linux-x86_64/egg/keras_contrib/tests
# copying build/lib/keras_contrib/tests/optimizers.py -> build/bdist.linux-x86_64/egg/keras_contrib/tests
# copying build/lib/keras_contrib/tests/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/tests
# copying build/lib/keras_contrib/tests/metrics.py -> build/bdist.linux-x86_64/egg/keras_contrib/tests
# creating build/bdist.linux-x86_64/egg/keras_contrib/datasets
# copying build/lib/keras_contrib/datasets/coco.py -> build/bdist.linux-x86_64/egg/keras_contrib/datasets
# copying build/lib/keras_contrib/datasets/pascal_voc.py -> build/bdist.linux-x86_64/egg/keras_contrib/datasets
# copying build/lib/keras_contrib/datasets/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/datasets
# copying build/lib/keras_contrib/datasets/conll2000.py -> build/bdist.linux-x86_64/egg/keras_contrib/datasets
# creating build/bdist.linux-x86_64/egg/keras_contrib/layers
# copying build/lib/keras_contrib/layers/crf.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers
# copying build/lib/keras_contrib/layers/capsule.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers
# copying build/lib/keras_contrib/layers/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers
# creating build/bdist.linux-x86_64/egg/keras_contrib/layers/normalization
# copying build/lib/keras_contrib/layers/normalization/instancenormalization.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/normalization
# copying build/lib/keras_contrib/layers/normalization/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/normalization
# copying build/lib/keras_contrib/layers/normalization/groupnormalization.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/normalization
# creating build/bdist.linux-x86_64/egg/keras_contrib/layers/convolutional
# copying build/lib/keras_contrib/layers/convolutional/cosineconvolution2d.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/convolutional
# copying build/lib/keras_contrib/layers/convolutional/subpixelupscaling.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/convolutional
# copying build/lib/keras_contrib/layers/convolutional/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/convolutional
# copying build/lib/keras_contrib/layers/core.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers
# creating build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations
# copying build/lib/keras_contrib/layers/advanced_activations/srelu.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations
# copying build/lib/keras_contrib/layers/advanced_activations/pelu.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations
# copying build/lib/keras_contrib/layers/advanced_activations/sinerelu.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations
# copying build/lib/keras_contrib/layers/advanced_activations/swish.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations
# copying build/lib/keras_contrib/layers/advanced_activations/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations
# creating build/bdist.linux-x86_64/egg/keras_contrib/initializers
# copying build/lib/keras_contrib/initializers/convaware.py -> build/bdist.linux-x86_64/egg/keras_contrib/initializers
# copying build/lib/keras_contrib/initializers/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/initializers
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/optimizers/padam.py to padam.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/optimizers/yogi.py to yogi.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/optimizers/ftml.py to ftml.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/optimizers/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/optimizers/lars.py to lars.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/wrappers/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/backend/numpy_backend.py to numpy_backend.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/backend/cntk_backend.py to cntk_backend.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/backend/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/backend/theano_backend.py to theano_backend.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/backend/tensorflow_backend.py to tensorflow_backend.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/preprocessing/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/utils/save_load_utils.py to save_load_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/utils/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/utils/conv_utils.py to conv_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/utils/test_utils.py to test_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/callbacks/snapshot.py to snapshot.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/callbacks/dead_relu_detector.py to dead_relu_detector.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/callbacks/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/callbacks/tensorboard.py to tensorboard.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/callbacks/cyclical_learning_rate.py to cyclical_learning_rate.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/constraints/clip.py to clip.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/constraints/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/applications/densenet.py to densenet.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/applications/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/applications/nasnet.py to nasnet.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/applications/resnet.py to resnet.cpython-310.pyc
# build/bdist.linux-x86_64/egg/keras_contrib/applications/resnet.py:413: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if include_top and top is 'classification':
# build/bdist.linux-x86_64/egg/keras_contrib/applications/resnet.py:417: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif include_top and top is 'segmentation':
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/applications/wide_resnet.py to wide_resnet.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/activations/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/activations/squash.py to squash.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/metrics/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/metrics/crf_accuracies.py to crf_accuracies.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/regularizers/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/losses/crf_losses.py to crf_losses.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/losses/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/losses/jaccard.py to jaccard.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/losses/dssim.py to dssim.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/tests/activations.py to activations.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/tests/regularizers.py to regularizers.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/tests/optimizers.py to optimizers.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/tests/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/tests/metrics.py to metrics.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/datasets/coco.py to coco.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/datasets/pascal_voc.py to pascal_voc.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/datasets/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/datasets/conll2000.py to conll2000.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/crf.py to crf.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/capsule.py to capsule.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/normalization/instancenormalization.py to instancenormalization.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/normalization/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/normalization/groupnormalization.py to groupnormalization.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/convolutional/cosineconvolution2d.py to cosineconvolution2d.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/convolutional/subpixelupscaling.py to subpixelupscaling.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/convolutional/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/core.py to core.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations/srelu.py to srelu.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations/pelu.py to pelu.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations/sinerelu.py to sinerelu.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations/swish.py to swish.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/initializers/convaware.py to convaware.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/initializers/__init__.py to __init__.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying keras_contrib.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying keras_contrib.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying keras_contrib.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying keras_contrib.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying keras_contrib.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/keras_contrib-2.0.8-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing keras_contrib-2.0.8-py3.10.egg
# Copying keras_contrib-2.0.8-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding keras-contrib 2.0.8 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/keras_contrib-2.0.8-py3.10.egg
# Processing dependencies for keras-contrib==2.0.8
# Searching for keras==2.15.0
# Best match: keras 2.15.0
# Adding keras 2.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Finished processing dependencies for keras-contrib==2.0.8

# %%
import keras_contrib

# %%
# !pip install natsort
# Out:
# Collecting natsort
#   Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Installing collected packages: natsort
# Successfully installed natsort-8.4.0

# %%
from __future__ import print_function, division

from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, Concatenate, BatchNormalization, Activation, ZeroPadding2D
# from keras.layers.advanced_activations import LeakyReLU
from tensorflow.keras.layers import LeakyReLU
# from keras.layers.convolutional import UpSampling2D, Conv2D
from tensorflow.keras.layers import UpSampling2D, Conv2D
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam

from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img

#from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import numpy as np
import datetime
import natsort
import scipy
import sys
import os
import cv2

# %%
from random import shuffle
import natsort
import numpy as np
import datetime
import matplotlib.pyplot as plt
import scipy
import sys
import os
import cv2

# %%
def load_filename(path):
    dirFiles = os.listdir(path)
    for i, file in enumerate(dirFiles):
        dirFiles[i] = path + file
    return natsort.natsorted(dirFiles ,reverse=False)

# load all images in a directory into memory
def load_images(list_path, size=(256, 256)):
    img_list = list()
    # enumerate filenames in directory, assume all are images
    for filename in list_path:
        # load and resize the image
        pixels = load_img(filename, target_size=size)
        # convert to numpy array
        pixels = img_to_array(pixels)
        pixels = (pixels - 127.5) / 127.5
        img_list.append(pixels)
    return np.asarray(img_list)

# %%
# select a batch of random samples, returns images and target
def generate_real_samples(dataset, n_samples, patch_shape):
    # unpack dataset
    trainA, trainB = dataset

    # choose random instances
    ix = np.random.randint(0, trainA.shape[0], n_samples)

    # retrieve selected images
    X1, X2 = trainA[ix], trainB[ix]

    # generate 'real' class labels (1)
    y = np.ones((n_samples, patch_shape, patch_shape, 1))

    return [X1, X2], y

# generate a batch of images, returns images and targets
def generate_fake_samples(g_model, samples, patch_shape):
    # generate fake instance
    X = g_model.predict(samples)

    # create 'fake' class labels (0)
    y = np.zeros((len(X), patch_shape, patch_shape, 1))

    return X, y

# %%
# generate samples and save as a plot and save the model
def summarize_performance(step, g_model, d_model, dataset, target_dir='', n_samples=3):
    if target_dir and not os.path.exists(target_dir):
        os.mkdir(target_dir)
    # select a sample of input images
    [X_realA, X_realB], _ = generate_real_samples(dataset, n_samples, 1)
    # generate a batch of fake samples
    X_fakeB, _ = generate_fake_samples(g_model, X_realA, 1)
    # scale all pixels from [-1,1] to [0,1]
    X_realA = (X_realA + 1) / 2.0
    X_realB = (X_realB + 1) / 2.0
    X_fakeB = (X_fakeB + 1) / 2.0
    # plot real source images
    for i in range(n_samples):
        plt.subplot(3, n_samples, 1 + i)
        plt.axis('off')
        plt.imshow(X_realA[i])
    # plot generated target image
    for i in range(n_samples):
        plt.subplot(3, n_samples, 1 + n_samples + i)
        plt.axis('off')
        plt.imshow(X_fakeB[i])
    # plot real target image
    for i in range(n_samples):
        plt.subplot(3, n_samples, 1 + n_samples*2 + i)
        plt.axis('off')
        plt.imshow(X_realB[i])
    # save plot to file
    filename1 = 'plot_%06d.png' % (step+1)
    plt.savefig(target_dir + filename1)
    plt.close()
    # save the generator model
    g_model.save(target_dir + 'g_model.h5')

    # save the discriminator model
    d_model.save(target_dir + 'd_model.h5')

    print('>Saved: %s and %s' % (filename1, 'g_model & d_model'))

# %%
def generator(img_shape):
    def conv2d(layer_in, n_filter, norm=True):
        d = Conv2D(n_filter, kernel_size=4, strides=2, padding='same')(layer_in)
        d = LeakyReLU(0.2)(d)
        if norm:
            d = InstanceNormalization()(d)
        return d

    def deconv2d(layer_in, skip_in, n_filter, dropout=0.5):
        d = UpSampling2D(size=2)(layer_in)
        d = Conv2D(n_filter, kernel_size=4, strides=1, padding='same', activation='relu')(d)
        if dropout:
            d = Dropout(dropout)(d)
        d = InstanceNormalization()(d)
        d = Concatenate()([d, skip_in])
        return d

    # Input Layer
    in_img = Input(shape=img_shape)

    # Downsampling
    d1 = conv2d(in_img, 64, norm=False)
    d2 = conv2d(d1, 128)
    d3 = conv2d(d2, 256)
    d4 = conv2d(d3, 512)
    d5 = conv2d(d4, 512)
    d6 = conv2d(d5, 512)
    d7 = conv2d(d6, 512)

    # Upsampling
    u1 = deconv2d(d7, d6, 512)
    u2 = deconv2d(u1, d5, 512)
    u3 = deconv2d(u2, d4, 512)
    u4 = deconv2d(u3, d3, 256, dropout=0)
    u5 = deconv2d(u4, d2, 128, dropout=0)
    u6 = deconv2d(u5, d1, 64, dropout=0)
    u7 = UpSampling2D(size=2)(u6)

    out_img = Conv2D(3, kernel_size=4, strides=1, padding='same', activation='tanh')(u7)

    return Model(in_img, out_img, name='generator')

# %%
def discriminator(img_shape):
    def d_layer(layer_in, n_filter, norm=True):
        d = Conv2D(n_filter, kernel_size=4, strides=2, padding='same')(layer_in)
        d = LeakyReLU(0.2)(d)
        if norm:
            d = InstanceNormalization()(d)
        return d

    in_src_img = Input(shape=img_shape)
    in_target_img = Input(shape=img_shape)

    merged = Concatenate()([in_src_img, in_target_img])

    d1 = d_layer(merged, 64, norm=False)
    d2 = d_layer(d1, 128)
    d3 = d_layer(d1, 256)
    d4 = d_layer(d1, 512)

    out = Conv2D(1, kernel_size=4, strides=1, padding='same')(d4)

    return Model([in_src_img, in_target_img], out, name='discriminator')

# %%
def GAN(g_model, d_model, img_shape):
    d_model.trainable = False
    in_img = Input(shape=img_shape)
    gen_out = g_model(in_img)
    dis_out = d_model([in_img, gen_out])
    model = Model(in_img, [dis_out, gen_out], name='GAN')
    return model

# %%
def train(d_model, g_model, gan_model, data, target_dir, n_epochs=100, n_batch=16):


    if any(element is None for element in data):
      raise ValueError("Data elements cannot be None. Check data loading process.")


    # determine the output square shape of the discriminator
    n_patch = d_model.output_shape[1]

    blue_photo = data[0]
    blue_sketch = data[1]
    # print(type(blue_photo), type(blue_sketch))

    for i in range(n_epochs):
        print(' ========== Epoch', i+1, '========== ')

        print("check 1")
        #print(blue_sketch)
        #x = shuffle([1,2,3,4,5,6],2)
        #print(x)
        shuffle(blue_photo)
        shuffle(blue_sketch)

        print("check 1.5")
        for j in range(int(len(blue_photo)/n_batch)):

            start = int(j*n_batch)
            end = int(min(len(blue_photo), (j*n_batch)+n_batch))

            print("check 2")
            dataset = [load_images(blue_photo[start:end]), load_images(blue_sketch[start:end])]

            print("check 3")
            # select a batch of real samples
            [X_realA, X_realB], y_real = generate_real_samples(dataset, n_batch, n_patch)

            print("check 4")
            # generate a batch of fake samples
            X_fakeB, y_fake = generate_fake_samples(g_model, X_realA, n_patch)

            print("check 5")
            # update discriminator for real samples
            d_loss1 = d_model.train_on_batch([X_realA, X_realB], y_real)

            print("check 6")
            # update discriminator for generated samples
            d_loss2 = d_model.train_on_batch([X_realA, X_fakeB], y_fake)

            print("check 7")

            d_loss = 0.5 * np.add(d_loss1, d_loss2)

            print("check 8", gan_model.train_on_batch(X_realA, [y_real, X_realB]))

            # update the generator
            g_loss, _, _ = gan_model.train_on_batch(X_realA, [y_real, X_realB])

            print("check 9")

            # summarize performance
            print('Batch : %d, D Loss : %.3f | G Loss : %.3f' % (j+1, d_loss, g_loss))

            print("check 10")
        # summarize model performance
#         if (i+1) % 10 == 0:
        summarize_performance(i, g_model, d_model, dataset, target_dir)

# %%
import tensorflow as tf
import keras.backend as K
from keras.losses import mean_absolute_error

def pixel_loss(y_true, y_pred):
    return K.mean(K.abs(y_true - y_pred))

def contextual_loss (y_true, y_pred):
    a = tf.image.rgb_to_grayscale(tf.slice(
                                y_pred,
                                [0,0,0,0],
                                [16, 256, 256, 3]))

    b = tf.image.rgb_to_grayscale(tf.slice(
                                y_true,
                                [0,0,0,0],
                                [16, 256, 256, 3]))

    y_pred = tf.divide(tf.add(tf.reshape(a, [tf.shape(a)[0], -1]), 1), 2)
    y_true = tf.divide(tf.add(tf.reshape(b, [tf.shape(b)[0], -1]), 1), 2)

#     tf.assert_rank(y_true,2)
#     tf.assert_rank(y_pred,2)

    p_shape = tf.shape(y_true)
    q_shape = tf.shape(y_pred)
#     tf.assert_equal(p_shape, q_shape)

    # normalize sum to 1
    p_ = tf.divide(y_true, tf.tile(tf.expand_dims(tf.reduce_sum(y_true, axis=1), 1), [1,p_shape[1]]))
    q_ = tf.divide(y_pred, tf.tile(tf.expand_dims(tf.reduce_sum(y_pred, axis=1), 1), [1,p_shape[1]]))

    return tf.reduce_sum(tf.multiply(p_, tf.math.log(tf.divide(p_, q_))), axis=1)

def total_loss (y_true, y_pred):

    px_loss = pixel_loss(y_true, y_pred)

    ctx_loss = contextual_loss(y_true, y_pred)

    return (0.2 * px_loss) + (0.8 * ctx_loss)

# %%
# # dataset path
# b_photo_path = '/content/gdrive/MyDrive/F-to-S/Dataset/Augmented_photo'
# b_sketch_path = '/content/gdrive/MyDrive/F-to-S/Dataset/Augmented_sketch'

# blue_photo = load_filenames(b_photo_path)
# blue_sketch = load_filenames(b_sketch_path)

# %%
# !pip install natsort
# Out:
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (8.4.0)

# %%
import natsort

def load_filenames(directory):
    dir_files = os.listdir(directory)
    for i, file in enumerate(dir_files):
        dir_files[i] = os.path.join(directory, file)
    return natsort.natsorted(dir_files, reverse=False)

# %%
# dataset path
b_photo_path = '/content/gdrive/MyDrive/F-to-S/Dataset/Augmented_photo'
b_sketch_path = '/content/gdrive/MyDrive/F-to-S/Dataset/Augmented_sketch'

blue_photo = load_filenames(b_photo_path)
blue_sketch = load_filenames(b_sketch_path)

# %%
# img = cv2.imread(blue_photo[1102])
# if img is not None:
#     # Perform operations on the image
#     plt.imshow(cv2.cvtColor(cv2.imread(blue_photo[1102]).astype('uint8'), cv2.COLOR_BGR2RGB))
# else:
#     print("Failed to load image:", blue_photo[1102])

# %%
plt.imshow(cv2.cvtColor(cv2.imread(blue_photo[1105]).astype('uint8'), cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(cv2.imread(blue_sketch[1105]).astype('uint8'), cv2.COLOR_BGR2RGB))

# %%
img_shape = (256, 256, 3)

d_model = discriminator(img_shape)

g_model = generator(img_shape)

gan_model = GAN(g_model, d_model, img_shape)

# %%
gan_model.summary()
# Out:
# Model: "GAN"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  generator (Functional)      (None, 256, 256, 3)          4182569   ['input_4[0][0]']
#                                                           1
#
#  discriminator (Functional)  (None, 64, 64, 1)            539203    ['input_4[0][0]',
#                                                                      'generator[0][0]']
#
# ==================================================================================================
# Total params: 42364894 (161.61 MB)
# Trainable params: 41825691 (159.55 MB)
# Non-trainable params: 539203 (2.06 MB)
# __________________________________________________________________________________________________

# %%
opt = Adam(lr=2e-4, beta_1=0.5)

d_model.compile(loss='binary_crossentropy', optimizer=opt, loss_weights=[0.5])
gan_model.compile(loss=['binary_crossentropy', total_loss], optimizer=opt, loss_weights=[1,100])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
import tensorflow as tf

# %%
def flatten_metrics_in_order(logs, metrics_names):
    if logs is not None:
        results = []
        for name in metrics_names:
            if name in logs:
                results.append(logs[name])
        for key in sorted(logs.keys()):
            if key not in metrics_names:
                results.append(logs[key])
        return results
    else:
        return []

# %%
os.mkdir('/content/Models')

# %%
os.mkdir('/content/Models/Pixel[02]_Context[08]/')

# %%
# os.mkdir('/content/gdrive/MyDrive/Models/')

# %%
from keras.preprocessing.image import load_img, img_to_array

# %%
# from PIL import Image
# import numpy as np

# def load_image(file_path, target_size):
#     img = Image.open(file_path)
#     img = img.resize(target_size)
#     return np.array(img)

# # Example usage:
# image = load_image("path_to_image.jpg", (width, height))

# %%
train(d_model, g_model, gan_model, [blue_sketch, blue_photo], '/content/gdrive/MyDrive/Models/', n_epochs = 8, n_batch=16)
# Out:
#  ========== Epoch 1 ==========
# check 1
# check 1.5
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 1s/step
# check 5
# check 6
# check 7
# check 8 [30.50213623046875, 12.065829277038574, 0.18436305224895477]
# check 9
# Batch : 1, D Loss : 2.172 | G Loss : 20.222
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 658ms/step
# check 5
# check 6
# check 7
# check 8 [25.853931427001953, 4.039721488952637, 0.21814210712909698]
# check 9
# Batch : 2, D Loss : 2.363 | G Loss : 25.438
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 641ms/step
# check 5
# check 6
# check 7
# check 8 [24.125154495239258, 3.7973787784576416, 0.20327776670455933]
# check 9
# Batch : 3, D Loss : 2.361 | G Loss : 22.523
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 645ms/step
# check 5
# check 6
# check 7
# check 8 [33.745513916015625, 1.516694188117981, 0.3222882151603699]
# check 9
# Batch : 4, D Loss : 2.885 | G Loss : 23.201
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 649ms/step
# check 5
# check 6
# check 7
# check 8 [20.54505729675293, 2.539746046066284, 0.18005311489105225]
# check 9
# Batch : 5, D Loss : 2.477 | G Loss : 18.269
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 638ms/step
# check 5
# check 6
# check 7
# check 8 [21.19496726989746, 2.1965651512145996, 0.1899840086698532]
# check 9
# Batch : 6, D Loss : 2.889 | G Loss : 20.473
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 638ms/step
# check 5
# check 6
# check 7
# check 8 [19.349777221679688, 2.3663582801818848, 0.1698341965675354]
# check 9
# Batch : 7, D Loss : 2.737 | G Loss : 19.608
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 654ms/step
# check 5
# check 6
# check 7
# check 8 [17.249900817871094, 2.0758190155029297, 0.15174081921577454]
# check 9
# Batch : 8, D Loss : 2.573 | G Loss : 16.556
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 657ms/step
# check 5
# check 6
# check 7
# check 8 [17.983013153076172, 2.2256667613983154, 0.15757346153259277]
# check 9
# Batch : 9, D Loss : 2.708 | G Loss : 18.722
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 671ms/step
# check 5
# check 6
# check 7
# check 8 [18.17273712158203, 2.6083221435546875, 0.15564414858818054]
# check 9
# Batch : 10, D Loss : 2.580 | G Loss : 18.451
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 622ms/step
# check 5
# check 6
# check 7
# check 8 [18.012062072753906, 2.119884967803955, 0.15892177820205688]
# check 9
# Batch : 11, D Loss : 2.897 | G Loss : 17.397
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 647ms/step
# check 5
# check 6
# check 7
# check 8 [17.587905883789062, 1.9809743165969849, 0.1560693085193634]
# check 9
# Batch : 12, D Loss : 2.572 | G Loss : 17.424
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 658ms/step
# check 5
# check 6
# check 7
# check 8 [18.70013427734375, 2.074456214904785, 0.16625678539276123]
# check 9
# Batch : 13, D Loss : 2.639 | G Loss : 18.137
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 626ms/step
# check 5
# check 6
# check 7
# check 8 [18.886642456054688, 2.0737388134002686, 0.16812904179096222]
# check 9
# Batch : 14, D Loss : 2.541 | G Loss : 17.850
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 664ms/step
# check 5
# check 6
# check 7
# check 8 [15.114662170410156, 1.8583269119262695, 0.13256335258483887]
# check 9
# Batch : 15, D Loss : 2.974 | G Loss : 16.276
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 654ms/step
# check 5
# check 6
# check 7
# check 8 [15.870806694030762, 1.90904700756073, 0.13961759209632874]
# check 9
# Batch : 16, D Loss : 2.614 | G Loss : 15.581
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 669ms/step
# check 5
# check 6
# check 7
# check 8 [16.14095115661621, 2.043013095855713, 0.14097937941551208]
# check 9
# Batch : 17, D Loss : 2.653 | G Loss : 15.992
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 650ms/step
# check 5
# check 6
# check 7
# check 8 [18.470993041992188, 1.7573236227035522, 0.16713668406009674]
# check 9
# Batch : 18, D Loss : 2.570 | G Loss : 17.491
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 666ms/step
# check 5
# check 6
# check 7
# check 8 [19.205087661743164, 1.7179862260818481, 0.17487099766731262]
# check 9
# Batch : 19, D Loss : 3.129 | G Loss : 18.979
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 663ms/step
# check 5
# check 6
# check 7
# check 8 [15.152624130249023, 1.8841509819030762, 0.13268473744392395]
# check 9
# Batch : 20, D Loss : 2.513 | G Loss : 15.070
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 652ms/step
# check 5
# check 6
# check 7
# check 8 [12.902287483215332, 1.9472919702529907, 0.10954994708299637]
# check 9
# Batch : 21, D Loss : 2.317 | G Loss : 13.444
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 653ms/step
# check 5
# check 6
# check 7
# check 8 [17.559425354003906, 2.011599540710449, 0.15547825396060944]
# check 9
# Batch : 22, D Loss : 2.726 | G Loss : 17.281
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 653ms/step
# check 5
# check 6
# check 7
# check 8 [15.26345443725586, 1.8666720390319824, 0.1339678168296814]
# check 9
# Batch : 23, D Loss : 2.382 | G Loss : 15.317
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 670ms/step
# check 5
# check 6
# check 7
# check 8 [16.132610321044922, 2.17324161529541, 0.1395936906337738]
# check 9
# Batch : 24, D Loss : 2.388 | G Loss : 16.082
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 668ms/step
# check 5
# check 6
# check 7
# check 8 [16.000566482543945, 2.296952247619629, 0.13703614473342896]
# check 9
# Batch : 25, D Loss : 2.444 | G Loss : 15.964
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 650ms/step
# check 5
# check 6
# check 7
# check 8 [15.214591979980469, 1.861673355102539, 0.1335291862487793]
# check 9
# Batch : 26, D Loss : 2.770 | G Loss : 15.104
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 638ms/step
# check 5
# check 6
# check 7
# check 8 [13.615728378295898, 1.826339840888977, 0.11789388954639435]
# check 9
# Batch : 27, D Loss : 2.487 | G Loss : 14.136
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 624ms/step
# check 5
# check 6
# check 7
# check 8 [17.21968650817871, 2.4195199012756348, 0.14800167083740234]
# check 9
# Batch : 28, D Loss : 2.472 | G Loss : 17.676
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 638ms/step
# check 5
# check 6
# check 7
# check 8 [16.351776123046875, 1.7711126804351807, 0.14580664038658142]
# check 9
# Batch : 29, D Loss : 2.857 | G Loss : 16.351
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 654ms/step
# check 5
# check 6
# check 7
# check 8 [13.845800399780273, 1.9649808406829834, 0.11880819499492645]
# check 9
# Batch : 30, D Loss : 2.393 | G Loss : 13.702
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 670ms/step
# check 5
# check 6
# check 7
# check 8 [18.25804901123047, 3.2167205810546875, 0.15041327476501465]
# check 9
# Batch : 31, D Loss : 2.576 | G Loss : 16.865
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 669ms/step
# check 5
# check 6
# check 7
# check 8 [17.234397888183594, 1.7535041570663452, 0.15480893850326538]
# check 9
# Batch : 32, D Loss : 3.116 | G Loss : 17.187
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 662ms/step
# check 5
# check 6
# check 7
# check 8 [15.288819313049316, 1.4986802339553833, 0.1379013955593109]
# check 9
# Batch : 33, D Loss : 2.982 | G Loss : 15.194
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 653ms/step
# check 5
# check 6
# check 7
# check 8 [14.950583457946777, 1.3962252140045166, 0.1355435848236084]
# check 9
# Batch : 34, D Loss : 2.801 | G Loss : 14.508
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 664ms/step
# check 5
# check 6
# check 7
# check 8 [16.791488647460938, 1.5485734939575195, 0.15242916345596313]
# check 9
# Batch : 35, D Loss : 2.832 | G Loss : 16.792
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 655ms/step
# check 5
# check 6
# check 7
# check 8 [15.26414966583252, 1.1675851345062256, 0.14096564054489136]
# check 9
# Batch : 36, D Loss : 2.687 | G Loss : 15.505
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 663ms/step
# check 5
# check 6
# check 7
# check 8 [17.52354621887207, 1.557201862335205, 0.15966343879699707]
# check 9
# Batch : 37, D Loss : 2.686 | G Loss : 16.497
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 654ms/step
# check 5
# check 6
# check 7
# check 8 [19.143117904663086, 1.486108422279358, 0.1765700876712799]
# check 9
# Batch : 38, D Loss : 3.048 | G Loss : 18.191
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 669ms/step
# check 5
# check 6
# check 7
# check 8 [14.756631851196289, 1.3859496116638184, 0.13370682299137115]
# check 9
# Batch : 39, D Loss : 2.887 | G Loss : 14.843
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 659ms/step
# check 5
# check 6
# check 7
# check 8 [16.032184600830078, 1.4014320373535156, 0.14630752801895142]
# check 9
# Batch : 40, D Loss : 2.823 | G Loss : 15.785
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 628ms/step
# check 5
# check 6
# check 7
# check 8 [13.430334091186523, 1.4134266376495361, 0.12016908079385757]
# check 9
# Batch : 41, D Loss : 2.456 | G Loss : 13.517
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 678ms/step
# check 5
# check 6
# check 7
# check 8 [14.640820503234863, 1.5903387069702148, 0.1305048167705536]
# check 9
# Batch : 42, D Loss : 2.537 | G Loss : 14.419
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 647ms/step
# check 5
# check 6
# check 7
# check 8 [14.913378715515137, 1.3389004468917847, 0.13574478030204773]
# check 9
# Batch : 43, D Loss : 2.718 | G Loss : 14.612
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 663ms/step
# check 5
# check 6
# check 7
# check 8 [13.10685920715332, 1.4825589656829834, 0.11624300479888916]
# check 9
# Batch : 44, D Loss : 2.570 | G Loss : 12.951
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 653ms/step
# check 5
# check 6
# check 7
# check 8 [15.703278541564941, 1.497873067855835, 0.14205405116081238]
# check 9
# Batch : 45, D Loss : 2.769 | G Loss : 15.337
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 665ms/step
# check 5
# check 6
# check 7
# check 8 [16.032880783081055, 1.5382752418518066, 0.14494605362415314]
# check 9
# Batch : 46, D Loss : 2.681 | G Loss : 15.903
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 668ms/step
# check 5
# check 6
# check 7
# check 8 [15.186491966247559, 1.5252418518066406, 0.13661250472068787]
# check 9
# Batch : 47, D Loss : 2.742 | G Loss : 15.055
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 675ms/step
# check 5
# check 6
# check 7
# check 8 [15.157628059387207, 1.485621452331543, 0.13672006130218506]
# check 9
# Batch : 48, D Loss : 2.922 | G Loss : 15.045
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 647ms/step
# check 5
# check 6
# check 7
# check 8 [12.635112762451172, 1.5681573152542114, 0.11066955327987671]
# check 9
# Batch : 49, D Loss : 2.195 | G Loss : 11.808
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 663ms/step
# check 5
# check 6
# check 7
# check 8 [12.964022636413574, 1.7555723190307617, 0.11208450794219971]
# check 9
# Batch : 50, D Loss : 2.473 | G Loss : 12.926
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 660ms/step
# check 5
# check 6
# check 7
# check 8 [14.683279037475586, 1.8642463684082031, 0.1281903237104416]
# check 9
# Batch : 51, D Loss : 2.639 | G Loss : 14.060
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 659ms/step
# check 5
# check 6
# check 7
# check 8 [15.563153266906738, 1.9502630233764648, 0.13612890243530273]
# check 9
# Batch : 52, D Loss : 2.369 | G Loss : 15.174
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 668ms/step
# check 5
# check 6
# check 7
# check 8 [14.207992553710938, 1.7546226978302002, 0.12453370541334152]
# check 9
# Batch : 53, D Loss : 2.469 | G Loss : 14.034
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 655ms/step
# check 5
# check 6
# check 7
# check 8 [14.808406829833984, 1.7152483463287354, 0.13093158602714539]
# check 9
# Batch : 54, D Loss : 2.527 | G Loss : 14.791
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 644ms/step
# check 5
# check 6
# check 7
# check 8 [13.298480987548828, 1.9137333631515503, 0.11384747922420502]
# check 9
# Batch : 55, D Loss : 2.367 | G Loss : 13.366
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 670ms/step
# check 5
# check 6
# check 7
# check 8 [16.052623748779297, 1.87929368019104, 0.1417333036661148]
# check 9
# Batch : 56, D Loss : 2.727 | G Loss : 15.873
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 661ms/step
# check 5
# check 6
# check 7
# check 8 [15.051474571228027, 1.244424819946289, 0.1380704939365387]
# check 9
# Batch : 57, D Loss : 2.587 | G Loss : 14.102
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 625ms/step
# check 5
# check 6
# check 7
# check 8 [14.444518089294434, 1.3897842168807983, 0.13054734468460083]
# check 9
# Batch : 58, D Loss : 2.777 | G Loss : 14.825
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 628ms/step
# check 5
# check 6
# check 7
# check 8 [13.671890258789062, 1.5736865997314453, 0.12098203599452972]
# check 9
# Batch : 59, D Loss : 2.607 | G Loss : 13.311
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 668ms/step
# check 5
# check 6
# check 7
# check 8 [17.475366592407227, 1.3288525342941284, 0.16146515309810638]
# check 9
# Batch : 60, D Loss : 2.772 | G Loss : 16.220
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 628ms/step
# check 5
# check 6
# check 7
# check 8 [15.067373275756836, 1.4333442449569702, 0.13634029030799866]
# check 9
# Batch : 61, D Loss : 2.879 | G Loss : 14.524
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 658ms/step
# check 5
# check 6
# check 7
# check 8 [15.669655799865723, 1.4158666133880615, 0.1425378918647766]
# check 9
# Batch : 62, D Loss : 2.751 | G Loss : 18.420
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 642ms/step
# check 5
# check 6
# check 7
# check 8 [16.774539947509766, 1.4854209423065186, 0.15289118885993958]
# check 9
# Batch : 63, D Loss : 2.937 | G Loss : 16.454
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 658ms/step
# check 5
# check 6
# check 7
# check 8 [16.76593017578125, 1.4133355617523193, 0.1535259485244751]
# check 9
# Batch : 64, D Loss : 2.792 | G Loss : 15.425
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 665ms/step
# check 5
# check 6
# check 7
# check 8 [17.986774444580078, 1.2729432582855225, 0.16713830828666687]
# check 9
# Batch : 65, D Loss : 3.191 | G Loss : 16.497
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 672ms/step
# check 5
# check 6
# check 7
# check 8 [14.715166091918945, 1.2593753337860107, 0.13455790281295776]
# check 9
# Batch : 66, D Loss : 2.728 | G Loss : 14.735
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 656ms/step
# check 5
# check 6
# check 7
# check 8 [16.028432846069336, 1.2884001731872559, 0.14740031957626343]
# check 9
# Batch : 67, D Loss : 2.831 | G Loss : 16.306
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 670ms/step
# check 5
# check 6
# check 7
# check 8 [14.21487045288086, 1.409498929977417, 0.1280537098646164]
# check 9
# Batch : 68, D Loss : 2.451 | G Loss : 14.268
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 658ms/step
# check 5
# check 6
# check 7
# check 8 [16.50179100036621, 1.5082824230194092, 0.14993509650230408]
# check 9
# Batch : 69, D Loss : 2.844 | G Loss : 16.038
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 647ms/step
# check 5
# check 6
# check 7
# check 8 [17.713790893554688, 1.3129587173461914, 0.16400831937789917]
# check 9
# Batch : 70, D Loss : 2.907 | G Loss : 17.046
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 664ms/step
# check 5
# check 6
# check 7
# check 8 [16.24163246154785, 1.4222712516784668, 0.1481936126947403]
# check 9
# Batch : 71, D Loss : 3.013 | G Loss : 15.860
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 658ms/step
# check 5
# check 6
# check 7
# check 8 [13.55008316040039, 1.4250595569610596, 0.12125024199485779]
# check 9
# Batch : 72, D Loss : 2.420 | G Loss : 13.368
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 660ms/step
# check 5
# check 6
# check 7
# check 8 [14.98122787475586, 1.3415946960449219, 0.13639633357524872]
# check 9
# Batch : 73, D Loss : 2.649 | G Loss : 14.440
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 619ms/step
# check 5
# check 6
# check 7
# check 8 [15.825008392333984, 1.3642654418945312, 0.14460742473602295]
# check 9
# Batch : 74, D Loss : 2.656 | G Loss : 15.740
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 673ms/step
# check 5
# check 6
# check 7
# check 8 [13.137845039367676, 1.430753469467163, 0.11707091331481934]
# check 9
# Batch : 75, D Loss : 2.372 | G Loss : 12.444
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 644ms/step
# check 5
# check 6
# check 7
# check 8 [14.06717586517334, 1.9721592664718628, 0.12095016241073608]
# check 9
# Batch : 76, D Loss : 2.533 | G Loss : 13.869
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 670ms/step
# check 5
# check 6
# check 7
# check 8 [16.032390594482422, 1.6463830471038818, 0.1438600718975067]
# check 9
# Batch : 77, D Loss : 2.849 | G Loss : 15.847
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 635ms/step
# check 5
# check 6
# check 7
# check 8 [14.372314453125, 1.2641851902008057, 0.13108129799365997]
# check 9
# Batch : 78, D Loss : 2.575 | G Loss : 14.091
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 653ms/step
# check 5
# check 6
# check 7
# check 8 [17.432714462280273, 1.34555983543396, 0.16087155044078827]
# check 9
# Batch : 79, D Loss : 3.026 | G Loss : 16.722
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 643ms/step
# check 5
# check 6
# check 7
# check 8 [15.248970031738281, 1.3510326147079468, 0.13897937536239624]
# check 9
# Batch : 80, D Loss : 2.726 | G Loss : 14.909
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 627ms/step
# check 5
# check 6
# check 7
# check 8 [16.98904800415039, 1.4589320421218872, 0.15530115365982056]
# check 9
# Batch : 81, D Loss : 2.794 | G Loss : 16.350
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 667ms/step
# check 5
# check 6
# check 7
# check 8 [13.110541343688965, 1.468461275100708, 0.11642080545425415]
# check 9
# Batch : 82, D Loss : 2.330 | G Loss : 13.101
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 658ms/step
# check 5
# check 6
# check 7
# check 8 [14.154121398925781, 1.4950330257415771, 0.12659087777137756]
# check 9
# Batch : 83, D Loss : 2.600 | G Loss : 14.016
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 626ms/step
# check 5
# check 6
# check 7
# check 8 [15.395414352416992, 1.5999454259872437, 0.1379546970129013]
# check 9
# Batch : 84, D Loss : 2.897 | G Loss : 15.289
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 660ms/step
# check 5
# check 6
# check 7
# check 8 [14.836142539978027, 1.7985117435455322, 0.13037630915641785]
# check 9
# Batch : 85, D Loss : 2.930 | G Loss : 14.538
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 672ms/step
# check 5
# check 6
# check 7
# check 8 [14.432136535644531, 1.6785935163497925, 0.12753543257713318]
# check 9
# Batch : 86, D Loss : 2.610 | G Loss : 14.303
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 658ms/step
# check 5
# check 6
# check 7
# check 8 [14.622955322265625, 1.7662196159362793, 0.12856735289096832]
# check 9
# Batch : 87, D Loss : 2.603 | G Loss : 14.379
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 647ms/step
# check 5
# check 6
# check 7
# check 8 [13.730975151062012, 1.312631368637085, 0.12418343871831894]
# check 9
# Batch : 88, D Loss : 2.509 | G Loss : 13.440
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 643ms/step
# check 5
# check 6
# check 7
# check 8 [15.380451202392578, 1.4244285821914673, 0.13956022262573242]
# check 9
# Batch : 89, D Loss : 2.937 | G Loss : 15.341
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 655ms/step
# check 5
# check 6
# check 7
# check 8 [13.196026802062988, 1.390542984008789, 0.1180548369884491]
# check 9
# Batch : 90, D Loss : 2.587 | G Loss : 12.922
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 660ms/step
# check 5
# check 6
# check 7
# check 8 [15.182046890258789, 1.378493309020996, 0.13803553581237793]
# check 9
# Batch : 91, D Loss : 2.598 | G Loss : 14.999
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 664ms/step
# check 5
# check 6
# check 7
# check 8 [14.695751190185547, 1.3052160739898682, 0.1339053511619568]
# check 9
# Batch : 92, D Loss : 2.435 | G Loss : 13.311
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 653ms/step
# check 5
# check 6
# check 7
# check 8 [17.981353759765625, 1.7130687236785889, 0.16268286108970642]
# check 9
# Batch : 93, D Loss : 2.826 | G Loss : 16.664
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 668ms/step
# check 5
# check 6
# check 7
# check 8 [15.464903831481934, 1.3193062543869019, 0.1414559781551361]
# check 9
# Batch : 94, D Loss : 2.843 | G Loss : 15.374
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 655ms/step
# check 5
# check 6
# check 7
# check 8 [14.118104934692383, 1.6887192726135254, 0.12429384887218475]
# check 9
# Batch : 95, D Loss : 2.371 | G Loss : 14.194
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 630ms/step
# check 5
# check 6
# check 7
# check 8 [14.090068817138672, 1.9481661319732666, 0.1214190274477005]
# check 9
# Batch : 96, D Loss : 2.281 | G Loss : 16.877
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 620ms/step
# check 5
# check 6
# check 7
# check 8 [18.490280151367188, 1.0262548923492432, 0.1746402531862259]
# check 9
# Batch : 97, D Loss : 2.994 | G Loss : 15.775
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 637ms/step
# check 5
# check 6
# check 7
# check 8 [17.273601531982422, 1.4654842615127563, 0.15808117389678955]
# check 9
# Batch : 98, D Loss : 2.833 | G Loss : 15.917
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 636ms/step
# check 5
# check 6
# check 7
# check 8 [16.612192153930664, 1.2427914142608643, 0.1536940038204193]
# check 9
# Batch : 99, D Loss : 2.660 | G Loss : 15.631
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 661ms/step
# check 5
# check 6
# check 7
# check 8 [15.61326789855957, 1.1923614740371704, 0.14420905709266663]
# check 9
# Batch : 100, D Loss : 2.908 | G Loss : 15.499
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 655ms/step
# check 5
# check 6
# check 7
# check 8 [12.98051643371582, 1.1874094009399414, 0.117931067943573]
# check 9
# Batch : 101, D Loss : 2.694 | G Loss : 12.945
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 645ms/step
# check 5
# check 6
# check 7
# check 8 [13.50855827331543, 1.287205696105957, 0.12221352756023407]
# check 9
# Batch : 102, D Loss : 2.745 | G Loss : 13.549
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 661ms/step
# check 5
# check 6
# check 7
# check 8 [13.951346397399902, 1.292368769645691, 0.12658977508544922]
# check 9
# Batch : 103, D Loss : 2.586 | G Loss : 13.831
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 660ms/step
# check 5
# check 6
# check 7
# check 8 [15.39724349975586, 1.2950997352600098, 0.14102144539356232]
# check 9
# Batch : 104, D Loss : 2.846 | G Loss : 15.032
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 672ms/step
# check 5
# check 6
# check 7
# check 8 [14.445235252380371, 1.306186318397522, 0.13139048218727112]
# check 9
# Batch : 105, D Loss : 2.813 | G Loss : 14.453
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 656ms/step
# check 5
# check 6
# check 7
# check 8 [14.903556823730469, 1.2126377820968628, 0.13690918684005737]
# check 9
# Batch : 106, D Loss : 2.842 | G Loss : 14.981
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 665ms/step
# check 5
# check 6
# check 7
# check 8 [25.895118713378906, 1.1564106941223145, 0.2473870813846588]
# check 9
# Batch : 107, D Loss : 2.498 | G Loss : 24.738
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 631ms/step
# check 5
# check 6
# check 7
# check 8 [26.400053024291992, 0.8593637943267822, 0.2554068863391876]
# check 9
# Batch : 108, D Loss : 2.847 | G Loss : 25.326
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 637ms/step
# check 5
# check 6
# check 7
# check 8 [21.04570770263672, 1.1317782402038574, 0.1991392970085144]
# check 9
# Batch : 109, D Loss : 2.367 | G Loss : 20.456
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 655ms/step
# check 5
# check 6
# check 7
# check 8 [23.85195541381836, 1.8131822347640991, 0.22038772702217102]
# check 9
# Batch : 110, D Loss : 2.714 | G Loss : 24.167
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 665ms/step
# check 5
# check 6
# check 7
# check 8 [23.730792999267578, 1.7171227931976318, 0.22013670206069946]
# check 9
# Batch : 111, D Loss : 2.636 | G Loss : 26.690
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 682ms/step
# check 5
# check 6
# check 7
# check 8 [21.548398971557617, 1.5795189142227173, 0.19968879222869873]
# check 9
# Batch : 112, D Loss : 2.475 | G Loss : 22.067
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 662ms/step
# check 5
# check 6
# check 7
# check 8 [21.531530380249023, 1.301861047744751, 0.2022966891527176]
# check 9
# Batch : 113, D Loss : 2.742 | G Loss : 21.587
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 653ms/step
# check 5
# check 6
# check 7
# check 8 [20.96949577331543, 1.7117969989776611, 0.19257697463035583]
# check 9
# Batch : 114, D Loss : 2.589 | G Loss : 20.707
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 663ms/step
# check 5
# check 6
# check 7
# check 8 [22.2268123626709, 1.254680871963501, 0.20972131192684174]
# check 9
# Batch : 115, D Loss : 2.841 | G Loss : 22.118
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 643ms/step
# check 5
# check 6
# check 7
# check 8 [22.0643310546875, 1.2309808731079102, 0.20833349227905273]
# check 9
# Batch : 116, D Loss : 2.718 | G Loss : 22.061
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 617ms/step
# check 5
# check 6
# check 7
# check 8 [23.065052032470703, 0.9762023091316223, 0.22088849544525146]
# check 9
# Batch : 117, D Loss : 2.951 | G Loss : 22.087
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 660ms/step
# check 5
# check 6
# check 7
# check 8 [18.57914924621582, 1.1182466745376587, 0.17460903525352478]
# check 9
# Batch : 118, D Loss : 2.370 | G Loss : 18.301
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 661ms/step
# check 5
# check 6
# check 7
# check 8 [18.955018997192383, 1.501943826675415, 0.1745307594537735]
# check 9
# Batch : 119, D Loss : 2.490 | G Loss : 18.749
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 659ms/step
# check 5
# check 6
# check 7
# check 8 [20.26430320739746, 1.5241925716400146, 0.18740110099315643]
# check 9
# Batch : 120, D Loss : 2.528 | G Loss : 19.995
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 656ms/step
# check 5
# check 6
# check 7
# check 8 [19.750944137573242, 1.2871043682098389, 0.18463841080665588]
# check 9
# Batch : 121, D Loss : 2.582 | G Loss : 19.589
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 689ms/step
# check 5
# check 6
# check 7
# check 8 [17.733110427856445, 1.1710832118988037, 0.16562026739120483]
# check 9
# Batch : 122, D Loss : 2.129 | G Loss : 17.443
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 647ms/step
# check 5
# check 6
# check 7
# check 8 [20.19639015197754, 1.3299312591552734, 0.18866458535194397]
# check 9
# Batch : 123, D Loss : 2.510 | G Loss : 21.277
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 663ms/step
# check 5
# check 6
# check 7
# check 8 [20.04347801208496, 1.647727370262146, 0.18395750224590302]
# check 9
# Batch : 124, D Loss : 2.399 | G Loss : 19.402
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 657ms/step
# check 5
# check 6
# check 7
# check 8 [17.941646575927734, 0.944779634475708, 0.16996866464614868]
# check 9
# Batch : 125, D Loss : 2.439 | G Loss : 17.786
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 675ms/step
# check 5
# check 6
# check 7
# check 8 [18.535049438476562, 1.230473279953003, 0.17304576933383942]
# check 9
# Batch : 126, D Loss : 2.297 | G Loss : 18.548
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 651ms/step
# check 5
# check 6
# check 7
# check 8 [17.91812515258789, 1.068760871887207, 0.16849364340305328]
# check 9
# Batch : 127, D Loss : 2.392 | G Loss : 17.959
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 662ms/step
# check 5
# check 6
# check 7
# check 8 [18.707382202148438, 1.0122709274291992, 0.1769511103630066]
# check 9
# Batch : 128, D Loss : 2.489 | G Loss : 18.565
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 655ms/step
# check 5
# check 6
# check 7
# check 8 [20.91294288635254, 1.374848484992981, 0.19538092613220215]
# check 9
# Batch : 129, D Loss : 2.759 | G Loss : 22.032
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 667ms/step
# check 5
# check 6
# check 7
# check 8 [20.13495445251465, 1.4580779075622559, 0.1867687702178955]
# check 9
# Batch : 130, D Loss : 2.709 | G Loss : 19.753
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 661ms/step
# check 5
# check 6
# check 7
# check 8 [20.33754539489746, 1.0648703575134277, 0.1927267462015152]
# check 9
# Batch : 131, D Loss : 2.618 | G Loss : 20.308
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 669ms/step
# check 5
# check 6
# check 7
# check 8 [20.59025764465332, 1.0668786764144897, 0.1952337920665741]
# check 9
# Batch : 132, D Loss : 2.608 | G Loss : 20.350
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 663ms/step
# check 5
# check 6
# check 7
# check 8 [21.34967613220215, 1.221130609512329, 0.2012854665517807]
# check 9
# Batch : 133, D Loss : 2.832 | G Loss : 24.326
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 620ms/step
# check 5
# check 6
# check 7
# check 8 [21.89366340637207, 0.8033158779144287, 0.21090346574783325]
# check 9
# Batch : 134, D Loss : 2.932 | G Loss : 22.618
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 641ms/step
# check 5
# check 6
# check 7
# check 8 [21.27375602722168, 1.8354796171188354, 0.19438275694847107]
# check 9
# Batch : 135, D Loss : 2.356 | G Loss : 20.105
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 630ms/step
# check 5
# check 6
# check 7
# check 8 [22.026111602783203, 0.9788473844528198, 0.21047264337539673]
# check 9
# Batch : 136, D Loss : 2.757 | G Loss : 22.758
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 655ms/step
# check 5
# check 6
# check 7
# check 8 [20.444787979125977, 1.3323695659637451, 0.19112420082092285]
# check 9
# Batch : 137, D Loss : 2.510 | G Loss : 20.889
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 678ms/step
# check 5
# check 6
# check 7
# check 8 [18.386737823486328, 1.373096227645874, 0.17013642191886902]
# check 9
# Batch : 138, D Loss : 2.381 | G Loss : 20.142
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 655ms/step
# check 5
# check 6
# check 7
# check 8 [20.256145477294922, 0.8270256519317627, 0.19429118931293488]
# check 9
# Batch : 139, D Loss : 2.654 | G Loss : 19.635
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 653ms/step
# check 5
# check 6
# check 7
# check 8 [20.234683990478516, 1.5322153568267822, 0.18702468276023865]
# check 9
# Batch : 140, D Loss : 2.486 | G Loss : 19.606
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 641ms/step
# check 5
# check 6
# check 7
# check 8 [19.541101455688477, 0.9236986637115479, 0.18617403507232666]
# check 9
# Batch : 141, D Loss : 2.504 | G Loss : 19.278
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 620ms/step
# check 5
# check 6
# check 7
# check 8 [19.731319427490234, 1.3624945878982544, 0.1836882382631302]
# check 9
# Batch : 142, D Loss : 2.418 | G Loss : 19.663
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 680ms/step
# check 5
# check 6
# check 7
# check 8 [18.09480094909668, 1.0582365989685059, 0.17036564648151398]
# check 9
# Batch : 143, D Loss : 2.397 | G Loss : 18.055
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 653ms/step
# check 5
# check 6
# check 7
# check 8 [20.851633071899414, 1.2219159603118896, 0.19629716873168945]
# check 9
# Batch : 144, D Loss : 2.653 | G Loss : 20.801
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 625ms/step
# check 5
# check 6
# check 7
# check 8 [20.873977661132812, 1.1182222366333008, 0.19755755364894867]
# check 9
# Batch : 145, D Loss : 2.685 | G Loss : 20.825
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 658ms/step
# check 5
# check 6
# check 7
# check 8 [21.296142578125, 1.2002555131912231, 0.20095886290073395]
# check 9
# Batch : 146, D Loss : 2.798 | G Loss : 21.236
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 658ms/step
# check 5
# check 6
# check 7
# check 8 [18.308412551879883, 1.0632054805755615, 0.17245207726955414]
# check 9
# Batch : 147, D Loss : 2.314 | G Loss : 18.347
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 624ms/step
# check 5
# check 6
# check 7
# check 8 [19.449111938476562, 1.129162311553955, 0.18319949507713318]
# check 9
# Batch : 148, D Loss : 2.479 | G Loss : 19.394
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 670ms/step
# check 5
# check 6
# check 7
# check 8 [19.189796447753906, 1.239111065864563, 0.17950685322284698]
# check 9
# Batch : 149, D Loss : 2.504 | G Loss : 19.135
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 656ms/step
# check 5
# check 6
# check 7
# check 8 [18.3951416015625, 1.1681537628173828, 0.17226988077163696]
# check 9
# Batch : 150, D Loss : 2.345 | G Loss : 18.327
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 664ms/step
# check 5
# check 6
# check 7
# check 8 [19.030977249145508, 1.0310965776443481, 0.17999880015850067]
# check 9
# Batch : 151, D Loss : 2.422 | G Loss : 18.915
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 636ms/step
# check 5
# check 6
# check 7
# check 8 [20.19144058227539, 1.1461548805236816, 0.19045285880565643]
# check 9
# Batch : 152, D Loss : 2.643 | G Loss : 20.030
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 638ms/step
# check 5
# check 6
# check 7
# check 8 [19.85565185546875, 1.1683777570724487, 0.18687275052070618]
# check 9
# Batch : 153, D Loss : 2.605 | G Loss : 18.560
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 643ms/step
# check 5
# check 6
# check 7
# check 8 [16.4421329498291, 1.8382220268249512, 0.14603911340236664]
# check 9
# Batch : 154, D Loss : 2.281 | G Loss : 15.966
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 641ms/step
# check 5
# check 6
# check 7
# check 8 [15.892099380493164, 1.5095574855804443, 0.14382541179656982]
# check 9
# Batch : 155, D Loss : 2.460 | G Loss : 14.874
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 669ms/step
# check 5
# check 6
# check 7
# check 8 [15.17330265045166, 1.7144392728805542, 0.13458862900733948]
# check 9
# Batch : 156, D Loss : 2.408 | G Loss : 14.235
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 612ms/step
# check 5
# check 6
# check 7
# check 8 [15.26526165008545, 1.9858205318450928, 0.13279440999031067]
# check 9
# Batch : 157, D Loss : 2.276 | G Loss : 13.847
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 655ms/step
# check 5
# check 6
# check 7
# check 8 [14.607847213745117, 1.4832234382629395, 0.13124623894691467]
# check 9
# Batch : 158, D Loss : 2.600 | G Loss : 14.501
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 625ms/step
# check 5
# check 6
# check 7
# check 8 [15.690278053283691, 1.870186448097229, 0.13820090889930725]
# check 9
# Batch : 159, D Loss : 2.169 | G Loss : 13.661
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 656ms/step
# check 5
# check 6
# check 7
# check 8 [18.354307174682617, 1.281980276107788, 0.17072325944900513]
# check 9
# Batch : 160, D Loss : 2.545 | G Loss : 16.737
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 673ms/step
# check 5
# check 6
# check 7
# check 8 [13.748406410217285, 1.4572184085845947, 0.12291187793016434]
# check 9
# Batch : 161, D Loss : 2.427 | G Loss : 13.872
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 648ms/step
# check 5
# check 6
# check 7
# check 8 [14.392671585083008, 1.7617850303649902, 0.1263088583946228]
# check 9
# Batch : 162, D Loss : 2.537 | G Loss : 14.385
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 659ms/step
# check 5
# check 6
# check 7
# check 8 [16.87058448791504, 1.9330170154571533, 0.14937567710876465]
# check 9
# Batch : 163, D Loss : 2.569 | G Loss : 15.640
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 616ms/step
# check 5
# check 6
# check 7
# check 8 [14.76608943939209, 1.495652437210083, 0.13270437717437744]
# check 9
# Batch : 164, D Loss : 2.287 | G Loss : 14.220
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 618ms/step
# check 5
# check 6
# check 7
# check 8 [16.969697952270508, 1.3712549209594727, 0.15598443150520325]
# check 9
# Batch : 165, D Loss : 2.886 | G Loss : 16.996
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 669ms/step
# check 5
# check 6
# check 7
# check 8 [16.136119842529297, 1.3555548191070557, 0.14780564606189728]
# check 9
# Batch : 166, D Loss : 2.690 | G Loss : 17.363
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 663ms/step
# check 5
# check 6
# check 7
# check 8 [17.675254821777344, 1.62769615650177, 0.16047558188438416]
# check 9
# Batch : 167, D Loss : 2.782 | G Loss : 18.780
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 659ms/step
# check 5
# check 6
# check 7
# check 8 [18.19687271118164, 1.2463710308074951, 0.1695050299167633]
# check 9
# Batch : 168, D Loss : 2.866 | G Loss : 18.100
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 654ms/step
# check 5
# check 6
# check 7
# check 8 [17.70819091796875, 2.0249369144439697, 0.15683254599571228]
# check 9
# Batch : 169, D Loss : 2.582 | G Loss : 16.497
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 653ms/step
# check 5
# check 6
# check 7
# check 8 [17.976179122924805, 1.2335567474365234, 0.1674262285232544]
# check 9
# Batch : 170, D Loss : 3.015 | G Loss : 16.755
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 614ms/step
# check 5
# check 6
# check 7
# check 8 [15.313155174255371, 1.6669610738754272, 0.13646194338798523]
# check 9
# Batch : 171, D Loss : 2.679 | G Loss : 14.032
# check 10
# check 2
# check 3
# check 4
# 1/1 [==============================] - 1s 654ms/step
# check 5
# check 6
# check 7
# check 8 [12.079324722290039, 1.4225775003433228, 0.10656746476888657]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-ad8855b34dd4> in <cell line: 1>()
# ----> 1 train(d_model, g_model, gan_model, [blue_sketch, blue_photo], '/content/gdrive/MyDrive/Models/', n_epochs = 8, n_batch=16)
#
# <ipython-input-22-01077caa0b73> in train(d_model, g_model, gan_model, data, target_dir, n_epochs, n_batch)
#      55
#      56             # update the generator
# ---> 57             g_loss, _, _ = gan_model.train_on_batch(X_realA, [y_real, X_realB])
#      58
#      59             print("check 9")
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    2785             )
#    2786             self.train_function = self.make_train_function()
# -> 2787             logs = self.train_function(iterator)
#    2788
#    2789         logs = tf_utils.sync_to_numpy_or_python_type(logs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     866       # In this case we have created variables on the first call, so we run the
#     867       # defunned version which is guaranteed to never create variables.
# --> 868       return tracing_compilation.call_function(
#     869           args, kwds, self._no_variable_creation_config
#     870       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
